# %% [markdown]
# ### Python Logging
# #### Logging is a crucial aspect of any application, providing a way to track events, errors, and operational information. Python's built-in logging module offers a flexible framework for emitting log messages from Python programs. In this lesson, we will cover the basics of logging, including how to configure logging, log levels, and best practices for using logging in Python applications.

# %%
import logging

# %%
## Configure the basic logging settings
logging.basicConfig(level=logging.DEBUG) # There are other levels too

## lof messages with different severity levels
logging.debug("This is a debug message")
logging.info("This is an ifo message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is an ifo message
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %% [markdown]
# #### Log Levels
# Python's logging module has several log levels indicating the severity of events. The default levels are:
#
# DEBUG: Detailed information, typically of interest only when diagnosing problems.
#
# INFO: Confirmation that things are working as expected.
#
# WARNING: An indication that something unexpected happened or indicative of some problem in the near future (e.g., ‘disk space low’). The software is still working as expected.
#
# ERROR: Due to a more serious problem, the software has not been able to perform some function.
#
# CRITICAL: A very serious error, indicating that the program itself may be unable to continue running.

# %%
## Configuring logging (How the logging messages should look)
logging.basicConfig(
    filename='app.log',  # We have added first two lines to save this basic config for this in a file
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True # Using force this time cuz i have configured before it is not allowed ot configure twice or subsequently in single
    
)
# Checking
logging.debug("This is a debug message")
logging.info("This is an ifo message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

# %% [markdown]
# ##### Making a logs folder as an example to use logging:
# It is an example how I can use logging to my advantage:
#
# <pre>📦Day 11
#  ┣ 📂logs
#  ┃ ┣ 📂__pycache__
#  ┃ ┃ ┗ 📜logger.cpython-314.pyc
#  ┃ ┣ 📜app.log
#  ┃ ┣ 📜logger.py
#  ┃ ┗ 📜test.py
#  ┣ 📜app.log
#  ┗ 📜LoggingPracticalImplementation.ipynb</pre>
